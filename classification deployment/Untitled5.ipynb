# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\healthcare.csv")
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112565    299.000000
# 75%       68.000000    37733.913725    400.000000
# max       85.000000    49995.902280    500.000000

# %% [markdown]
# people between age group of 70 to 80 have highest frequency

# %%
df['Age'].plot(kind="hist",bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# amount 20000 has occured the most

# %%
df['Billing Amount'].plot(kind="hist",bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# room numbers near around 150 have highest frequency

# %%
df['Room Number'].plot(kind="hist",bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# finding information about columns with object data type

# %%
df.describe(include=['O'])
# Out:
#                    Name  Gender Blood Type Medical Condition  \
# count             10000   10000      10000             10000
# unique             9378       2          8                 6
# top     Michael Johnson  Female        AB-            Asthma
# freq                  7    5075       1275              1708
#
#        Date of Admission           Doctor   Hospital Insurance Provider  \
# count              10000            10000      10000              10000
# unique              1815             9416       8639                  5
# top            4/12/2019  Michael Johnson  Smith PLC              Cigna
# freq                  15                7         19               2040
#
#        Admission Type Discharge Date  Medication Test Results
# count           10000          10000       10000        10000
# unique              3           1834           5            3
# top            Urgent     11/28/2021  Penicillin     Abnormal
# ...

# %% [markdown]
# number of females more in comparision to males

# %%
# Assuming df['Category'] contains categorical data
category_counts = df['Gender'].value_counts()

plt.figure(figsize=(2, 2))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of gender')
plt.show()

# %% [markdown]
# many people have blood type AB-

# %%
category_counts = df['Blood Type'].value_counts()

plt.figure(figsize=(3, 3))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal') 
plt.title('Distribution of blood type')
plt.show()

# %% [markdown]
# many are with the medical condition of asthma

# %%
category_counts = df['Medical Condition'].value_counts()

plt.figure(figsize=(3, 3))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal') 
plt.title('Distribution of medical condition')
plt.show()

# %% [markdown]
# cigna is one of the most frequent insurance provider

# %%
category_counts = df['Insurance Provider'].value_counts()

plt.figure(figsize=(3, 3))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal') 
plt.title('Distribution of insurance')
plt.show()

# %% [markdown]
# urgent admissions have highest frequency

# %%
category_counts = df['Admission Type'].value_counts()

plt.figure(figsize=(3, 3))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal') 
plt.title('Distribution of admission type')
plt.show()

# %% [markdown]
# penicillin is most likely used medication

# %%
category_counts = df['Medication'].value_counts()

plt.figure(figsize=(3, 3))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal') 
plt.title('Distribution of medication')
plt.show()

# %% [markdown]
# abnormal test results is found more in comparision to inconclusive and normal

# %%
category_counts = df['Test Results'].value_counts()

plt.figure(figsize=(2, 2))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal') 
plt.title('Distribution of test results')
plt.show()

# %% [markdown]
# males have more billing amount in comparision to females

# %%
sns.lineplot(x='Gender',y='Billing Amount',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# people with blood group A- and AB+ have paid the maximum bill

# %%
sns.barplot(x='Blood Type',y='Billing Amount',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Blood Type', ylabel='Billing Amount'>

# %% [markdown]
# people having diabetes have paid the maximum bill

# %%
sns.barplot(x='Medical Condition',y='Billing Amount',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Medical Condition', ylabel='Billing Amount'>

# %% [markdown]
# 3 insurance providers have paid the maximum in comparision to the other two

# %%
sns.barplot(x='Insurance Provider',y='Billing Amount',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Insurance Provider', ylabel='Billing Amount'>

# %%
sns.barplot(x='Test Results',y='Billing Amount',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Test Results', ylabel='Billing Amount'>

# %% [markdown]
# people with inconculsive test result have paid the maximum

# %%
sns.lineplot(x='Test Results',y='Billing Amount',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
sns.barplot(x='Medical Condition',y='Billing Amount',data=df,hue='Medication')
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
sns.barplot(x='Medical Condition',y='Billing Amount',data=df,hue='Test Results')
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# extracting number of days from date of admission to discharge date

# %%
df['Date of Admission']= pd.to_datetime(df['Date of Admission'])
df['Discharge Date']= pd.to_datetime(df['Discharge Date'])
df['Days hospitalized'] = (df['Discharge Date'] - df['Date of Admission']).dt.days
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare     37490.98336          146       Elective
# ...

# %%
df = df[[ 'Age','Billing Amount','Room Number', 'Gender', 'Blood Type', 'Medical Condition','Insurance Provider', 'Admission Type', 'Medication', 'Test Results','Days hospitalized']]
df.head()
# Out:
#    Age  Billing Amount  Room Number  Gender Blood Type Medical Condition  \
# 0   81     37490.98336          146  Female         O-          Diabetes
# 1   35     47304.06485          404    Male         O+            Asthma
# 2   61     36874.89700          292    Male         B-           Obesity
# 3   49     23303.32209          480    Male         B-            Asthma
# 4   51     18086.34418          477    Male         O-         Arthritis
#
#   Insurance Provider Admission Type   Medication  Test Results  \
# 0           Medicare       Elective      Aspirin  Inconclusive
# 1   UnitedHealthcare      Emergency      Lipitor        Normal
# 2           Medicare      Emergency      Lipitor        Normal
# 3           Medicare         Urgent   Penicillin      Abnormal
# 4   UnitedHealthcare         Urgent  Paracetamol        Normal
#
#    Days hospitalized
# 0                 14
# 1                 14
# 2                 30
# 3                  1
# 4                 24

# %%
unique_values = df['Room Number'].unique()
print(unique_values)
# Out:
# [146 404 292 480 477 180 161 384 215 310 306 126 444 492 120 315 475 125
#  366 238 364 130 293 379 298 392 162 456 197 247 228 137 192 258 219 414
#  110 465 469 182 119 388 412 359 186 437 132 271 361 303 317 439 153 438
#  380 194 199 301 223 410 205 134 407 188 213 405 358 147 115 436 263 493
#  460 356 142 139 482 141 397 347 245 143 108 268 176 462 484 329 335 201
#  309 389 217 299 275 181 401 214 267 211 184 140 416 179 289 350 104 220
#  464 419 445 398 336 413 145 148 432 430 406 295 175 409 424 168 136 459
#  261 257 170 451 372 202 394 264 279 260 499 452 365 340 360 290 103 187
#  378 334 470 252 450 106 259 344 489 276 155 455 425 400 127 333 443 129
#  164 486 440 265 193 222 488 472 391 230 322 272 154 236 375 221 244 287
#  243 370 237 234 458 226 478 204 196 294 297 280 374 216 135 225 152 270
#  454 442 189 487 485 218 111 105 362 497 420 483 288 133 114 253 286 109
#  390 207 411 324 357 283 471 274 353 311 490 368 284 242 209 433 116 278
# ...

# %%
num_unique_ages = df['Billing Amount'].nunique()
print(num_unique_ages)
# Out:
# 10000

# %%
num_unique_ages = df['Days hospitalized'].nunique()
print(num_unique_ages)
# Out:
# 30

# %%
from sklearn.preprocessing import LabelEncoder
lc = LabelEncoder()
for col in df.columns:
    if col!=['Age','Billing Amount','Room Number','Days Hospitalized']:
        df[col]=lc.fit_transform(df[col])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12388\751970404.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=lc.fit_transform(df[col])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12388\751970404.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=lc.fit_transform(df[col])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12388\751970404.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.head()
# Out:
#    Age  Billing Amount  Room Number  Gender  Blood Type  Medical Condition  \
# 0   63            7439           45       0           7                  3
# 1   17            9444          303       1           6                  1
# 2   43            7329          191       1           5                  5
# 3   31            4589          379       1           5                  1
# 4   33            3469          376       1           7                  0
#
#    Insurance Provider  Admission Type  Medication  Test Results  \
# 0                   3               0           0             1
# 1                   4               1           2             2
# 2                   3               1           2             2
# 3                   3               2           4             0
# 4                   4               2           3             2
#
#    Days hospitalized
# 0                 13
# 1                 13
# 2                 29
# 3                  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 10000 non-null  int64
#  1   Billing Amount      10000 non-null  int64
#  2   Room Number         10000 non-null  int64
#  3   Gender              10000 non-null  int32
#  4   Blood Type          10000 non-null  int32
#  5   Medical Condition   10000 non-null  int32
#  6   Insurance Provider  10000 non-null  int32
#  7   Admission Type      10000 non-null  int32
#  8   Medication          10000 non-null  int32
#  9   Test Results        10000 non-null  int32
#  10  Days hospitalized   10000 non-null  int64
# dtypes: int32(7), int64(4)
# memory usage: 586.1 KB

# %%
sns.pairplot(df,hue='Days hospitalized',palette="bwr",diag_kind='hist')
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
sns.barplot(x='Days hospitalized',y='Billing Amount',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Days hospitalized', ylabel='Billing Amount'>

# %%
sns.scatterplot(x='Billing Amount',y='Days hospitalized',data=df,)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Billing Amount', ylabel='Days hospitalized'>

# %%
# KNN
x=df.drop(['Room Number','Billing Amount','Days hospitalized','Test Results'],axis=1)
y=df['Test Results']

# %%
x
# Out:
#       Age  Gender  Blood Type  Medical Condition  Insurance Provider  \
# 0      63       0           7                  3                   3
# 1      17       1           6                  1                   4
# 2      43       1           5                  5                   3
# 3      31       1           5                  1                   3
# 4      33       1           7                  0                   4
# ...   ...     ...         ...                ...                 ...
# 9995   65       1           0                  5                   4
# 9996   29       0           2                  0                   1
# 9997   36       1           5                  0                   1
# 9998   66       1           0                  0                   4
# 9999    2       1           5                  0                   0
#
#       Admission Type  Medication
# 0                  0           0
# 1                  1           2
# 2                  1           2
# ...

# %%
from sklearn import preprocessing
x=preprocessing.StandardScaler().fit_transform(x)
x
# Out:
# array([[ 1.50846482, -0.98511083,  1.53060631, ...,  0.72195234,
#         -1.24635266, -1.42459457],
#        [-0.83991244,  1.01511421,  1.09315274, ...,  1.42967936,
#         -0.01829801, -0.01466329],
#        [ 0.48743123,  1.01511421,  0.65569916, ...,  0.72195234,
#         -0.01829801, -0.01466329],
#        ...,
#        [ 0.13006947,  1.01511421,  0.65569916, ..., -0.69350171,
#         -1.24635266, -0.71962893],
#        [ 1.66161985,  1.01511421, -1.53156871, ...,  1.42967936,
#          1.20975664,  1.39526799],
#        [-1.60568763,  1.01511421,  0.65569916, ..., -1.40122873,
#         -0.01829801,  1.39526799]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33,random_state=42)

# %%
ks=25
mean_acc=np.zeros((ks-1))
# train as well as predict
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
for n in range(1,ks-1):
    neigh=KNeighborsClassifier(n_neighbors=n).fit(x_train,y_train)
    yhat=neigh.predict(x_test)
    mean_acc[n-1]=accuracy_score(y_test,yhat)

# %%
mean_acc
# Out:
# array([0.3469697 , 0.34787879, 0.34575758, 0.34545455, 0.34515152,
#        0.34090909, 0.34515152, 0.35272727, 0.34878788, 0.34969697,
#        0.34606061, 0.35030303, 0.34545455, 0.33787879, 0.34030303,
#        0.34151515, 0.33393939, 0.33606061, 0.33636364, 0.33727273,
#        0.35333333, 0.34242424, 0.33818182, 0.        ])

# %%
print("best accuracy was with",mean_acc.max(),"with k=",mean_acc.argmax())
# Out:
# best accuracy was with 0.35333333333333333 with k= 20

# %%
from sklearn.neighbors import KNeighborsClassifier
knnmodel=KNeighborsClassifier(n_neighbors=21)
knnmodel.fit(x_train,y_train)
y_predict1=knnmodel.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(y_test,y_predict1)
acc
# Out:
# 0.35333333333333333

# %%
# logistic
x=df.drop(['Room Number','Billing Amount','Days hospitalized','Test Results'],axis=1)
y=df['Test Results']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier=LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV
parameter={'penalty':['l1','l2','elasticnet'],'C':[0.5, 0.6, 0.7, 0.8],'max_iter':[100,200,300]}

# %%
classifier_regressor=GridSearchCV(classifier,param_grid=parameter,scoring='accuracy',cv=5)

# %%
classifier_regressor.fit(x_train,y_train)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(classifier_regressor.best_params_)
# Out:
# {'C': 0.5, 'max_iter': 100, 'penalty': 'l2'}

# %%
print(classifier_regressor.best_score_)
# Out:
# 0.3385333333333333

# %%
y_predi=classifier_regressor.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_predi,y_test)
score
# Out:
# 0.3384

# %%
# classification_report(y_predi,y_test)
print(classification_report(y_test,y_predi))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.58      0.44       883
#            1       0.31      0.32      0.31       786
#            2       0.35      0.10      0.16       831
#
#     accuracy                           0.34      2500
#    macro avg       0.34      0.33      0.30      2500
# weighted avg       0.34      0.34      0.31      2500

# %%
# SVM
x=df.drop(['Room Number','Days hospitalized','Billing Amount','Test Results','Insurance Provider'],axis=1)
y=df['Test Results']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25,random_state=42)

# %%
from sklearn.svm import SVC
model=SVC(kernel="linear")
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.3304

# %% [markdown]
# THEREFORE MAXIMUM ACCURACY IS 35% WITH KNN
