# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\winequalityred.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.shape
# Out:
# (1359, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
corr_data = df.corr()

# %%
plt.figure(figsize = (8, 8))
sns.heatmap(corr_data, cbar = True, square= True, annot=True, fmt= '.2f',  cmap='Blues')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
int_float_unique_counts = df.select_dtypes(include=['int64', 'float64']).nunique()
print(int_float_unique_counts)
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %% [markdown]
# quality 5 has maximum number of wines

# %%
counts = df['quality'].value_counts()

plt.figure(figsize=(5, 4))
counts.plot(kind='bar')
plt.xlabel('quality')
plt.ylabel('Count')
plt.title('wines in each quality')
plt.show()

# %% [markdown]
# wines have fixed acidity around 8. not much information as columns show negative correlation

# %%
sns.barplot(x = 'quality', y= 'fixed acidity', data = df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %% [markdown]
# Lesser the value of volatile acidity more are the chances of the wine to be of good quality.

# %%
sns.barplot(x = 'quality', y= 'volatile acidity', data = df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# The higher the content of citric acid more are the chances of wine quality be good

# %%
sns.barplot(x = 'quality', y= 'citric acid', data = df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# There is no correlation between residual sugar and quality column.Most of the wine is having sugar level less than 3.

# %%
sns.boxplot(x=df['quality'],y=df['residual sugar'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %% [markdown]
# The chloride level of most of the wine is less than 0.1.There is not much correlation between chlorides and quality of the wine.

# %%
sns.boxplot(x=df['quality'],y=df['chlorides'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='chlorides'>

# %% [markdown]
# There is not any correlation between free sulfur dioxide and quality column and hence no relation between quality and total sulfur dioxide

# %%
sns.boxplot(x=df['quality'],y=df['free sulfur dioxide'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %% [markdown]
# lower the density better the quality of the wine

# %%
sns.boxplot(x = 'quality', y = 'density', data = df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='density'>

# %% [markdown]
# Higher the content of sulphates the more chances of the wine to be good

# %%
sns.boxplot(x=df['quality'],y=df['sulphates'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='sulphates'>

# %% [markdown]
# More the content of the alcohol more are chances of  wine to be good quality

# %%
sns.boxplot(x=df['quality'],y=df['alcohol'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# Higer  alcohol content is causing density to decrease. All the good wine have high content of alcohol thus it has low density.

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['density'],y=df['alcohol'],hue=df['quality'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='density', ylabel='alcohol'>

# %% [markdown]
#  linear sort of relation between acidity and density. As acidity increases, density also tends to increase.

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['density'],y=df['fixed acidity'],hue=df['quality'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='density', ylabel='fixed acidity'>

# %% [markdown]
#  kind of linear relatioship between citric acid and acidity. Higher content of citric acid causes increase in acidity of wine  Most of the best wine are those who have higher content of citric acid.

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['citric acid'],y=df['fixed acidity'],hue=df['quality'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='citric acid', ylabel='fixed acidity'>

# %%
X=df.drop('quality',axis=1)
y=df['quality']

# %%
# RANDOM FOREST
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state= 42)

# %%
rfc=RandomForestRegressor()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_rfc_pred=rfc.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_rfc_pred)
r2
# Out:
# 0.42269749464377304

# %%
# LINEAR
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
mse=cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
mse
# Out:
# array([-0.39118334, -0.51729556, -0.50798591, -0.41648166, -0.45573774])

# %%
reg_pred=regression.predict(X_test)
reg_pred
# Out:
# array([5.23606025, 5.8044772 , 6.40169542, 5.16217766, 5.14200158,
#        6.78702667, 5.72167254, 4.84725819, 5.79725173, 5.73279695,
#        6.35909669, 5.90883775, 6.03015912, 5.53608439, 6.31798797,
#        5.27778868, 5.99347991, 5.30487553, 5.16236447, 5.87381468,
#        5.25417681, 6.17918013, 5.32356903, 4.77324906, 5.77573602,
#        4.78280285, 5.68528546, 5.37513774, 5.20712571, 5.32709516,
#        6.05062356, 6.37679887, 5.77073469, 4.65195803, 5.61950925,
#        6.27502161, 4.87109299, 5.88517735, 5.26518354, 6.18938113,
#        5.23868576, 5.78112475, 6.0323627 , 4.60619193, 5.42507966,
#        5.44172909, 5.04939799, 4.33877372, 5.20602442, 5.83658464,
#        5.49074686, 6.14124524, 5.90442297, 5.6319008 , 6.29540653,
#        5.17368039, 5.22528216, 5.21107745, 5.0257828 , 6.04963366,
#        4.88824793, 6.13598701, 5.15024281, 5.89625596, 5.78412784,
#        5.94707904, 5.10802673, 5.49003527, 6.15002882, 6.09469603,
# ...

# %%
from sklearn import metrics
r2_score=metrics.r2_score(y_test,reg_pred)
print("R2 score=",r2_score)
# Out:
# R2 score= 0.3685235065432392

# %%
# SVM
from sklearn.svm import SVR
model=SVR(kernel="linear")
model.fit(X_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
from sklearn.metrics import r2_score
y_pred=model.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.3725268702707826

# %%
# KNN
from sklearn import preprocessing
X=preprocessing.StandardScaler().fit_transform(X)
X
# Out:
# array([[-0.52443096,  0.93200015, -1.39325797, ...,  1.29187216,
#         -0.57856134, -0.95437429],
#        [-0.29406274,  1.91580043, -1.39325797, ..., -0.70839548,
#          0.12482157, -0.5845748 ],
#        [-0.29406274,  1.25993358, -1.18861732, ..., -0.32124691,
#         -0.05102416, -0.5845748 ],
#        ...,
#        [-1.38831178,  0.11216658, -0.88165635, ...,  1.35639693,
#          0.59374351,  0.7097234 ],
#        [-1.38831178,  0.63139451, -0.77933603, ...,  1.67902074,
#          0.3006673 , -0.21477532],
#        [-1.33071973, -1.19956712,  1.01126962, ...,  0.51757501,
#          0.00759108,  0.52482366]])

# %%
ks=25
mean_acc=np.zeros((ks-1))
# train as well as predict
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score
for n in range(1,ks-1):
    neigh=KNeighborsRegressor(n_neighbors=n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1]=r2_score(y_test,yhat)

# %%
mean_acc
# Out:
# array([-0.19908567,  0.09899212,  0.20249136,  0.20717235,  0.26591569,
#         0.30514378,  0.31847195,  0.31344724,  0.32765225,  0.32407473,
#         0.31622387,  0.32407944,  0.32736076,  0.34190617,  0.34483103,
#         0.35688605,  0.35677456,  0.35648567,  0.35895634,  0.36213893,
#         0.35615412,  0.35566012,  0.35641014,  0.        ])

# %%
print("best accuracy was with",mean_acc.max(),"with k=",mean_acc.argmax())
# Out:
# best accuracy was with 0.3621389261896858 with k= 19

# %%
from sklearn.neighbors import KNeighborsRegressor
knnmodel=KNeighborsRegressor(n_neighbors=20)
knnmodel.fit(X_train,y_train)
y_predict1=knnmodel.predict(X_test)

# %%
r2=r2_score(y_test,y_predict1)
r2
# Out:
# 0.3621389261896858

# %% [markdown]
# THEREFORE MAXIMUM ACCURACY IS 42% WITH RANDOM FOREST
